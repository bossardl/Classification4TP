# %%
path_training = 'train_img'
path_val = 'val_img'
label_file = 'label_train.txt'
# !python main.py --image_path "train_img" --label_path "label_train.txt" --batch_size 128 --lr 0.001 --epochs 100
# cd "C:\Users\lud44009\Documents\Practice\ml_exercise_therapanacea"
# cd tpenv\Scripts
# .\activate
# cd ..
# cd ..
# py main.py --image_path "train_img" --label_path "label_train.txt" --batch_size 128 --lr 0.001 --epochs 50
# Out:
# ############################ PREPROCESSING ############################
# Label du fichier label_train.txt
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
#
# Nombre de valeurs dans le df len(100000)- verification pas d'outlier
# label    2
# dtype: int64
#
#
# Nombre d'occurences de chaque label
# label
# 1        87898
# 0        12102
# Name: count, dtype: int64
#
#
# Figure(500x500)
#
#
# Shape des données (64, 64, 3)
# ##################################################################
#
#
#
#
# ###################  TRAINING & EVALUATION   #####################
#
#
# Model: "sequential"
# ┌─────────────────────────────────┬────────────────────────┬───────────────┐
# │ Layer (type)                    │ Output Shape           │       Param # │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 36)     │         1,008 │
# ...
